# %% [markdown]
# # ANALYSIS OF BIAS ON TINYBERT

# %%
from src.bias_computation import compute_bias_score

# read the txt file with attribute words
def read_attribute_words(file_path):
    with open(file_path, 'r') as f:
        words = [line.strip() for line in f if line.strip()]
    return words

attributes = read_attribute_words("data/tech_skills/in_demand_tech_skills.txt")

scores = compute_bias_score("[SUBJ] does [ATTR]", ("he", "she"), attributes)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[4], line 12
#       7     return words
#      10 attributes = read_attribute_words("data/tech_skills/in_demand_tech_skills.txt")
# ---> 12 scores = compute_bias_score("[SUBJ] does [ATTR]", ( "she"), attributes)
#
# File ~/bias-busters/src/bias_computation.py:77, in compute_bias_score(sentence, subject_words, attribute_words)
#      74 # sanity checks
#      75 assert "[SUBJ]" in sentence and "[ATTR]" in sentence, \
#      76     "Sentence must contain [SUBJ] and [ATTR] placeholders."
# ---> 77 assert len(subject_words) == 2, \
#      78     "There must be exactly two subject words."
#      80 # 1. sentence has to include "[SUBJ]", "[ATTR]"
#      81
#      82 # 3. Replace [SUBJ] with [MASK] to compute target probabilities
#      83 prior_subj_probs = get_mask_fill_probabilities(
#      84     sentence.replace("[ATTR]", "[MASK]").replace("[SUBJ]", "[MASK]"),
#      85     subject_words)
#
# AssertionError: There must be exactly two subject words.
