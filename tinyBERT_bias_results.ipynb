# %% [markdown]
# # ANALYSIS OF BIAS ON TINYBERT

# %%
from src.bias_computation import compute_bias_score

# read the txt file with attribute words
def read_attribute_words(file_path):
    with open(file_path, 'r') as f:
        words = [line.strip() for line in f if line.strip()]
    return words

attributes = read_attribute_words("data/tech_skills/in_demand_tech_skills.txt")

scores = compute_bias_score("[SUBJ] does [ATTR]", ("he", "she"), attributes)

# %%
scores
# Out:
# {'Cloud Computing': 2.376896381378174,
#  'Artificial Intelligence': 1.5865731239318848,
#  'Analytical Reasoning': 3.05790376663208,
#  'People Management': 0.4217820167541504,
#  'UX Design': -1.319624423980713,
#  'Mobile Application Development': 0.01898479461669922,
#  'Video Production': -0.8193304538726807,
#  'Sales Leadership': 0.5103154182434082,
#  'Translation': -0.5605735778808594,
#  'Audio Production': 0.817155122756958,
#  'Natural Language Processing': -0.6384139060974121,
#  'Scientific Computing': 3.4108142852783203,
#  'Game Development': 2.7982611656188965,
#  'Social Media Marketing': -0.36518239974975586,
#  'Animation': 1.0052905082702637,
#  'Business Analysis': 1.4333337545394897,
#  'Journalism': 0.3766012191772461,
#  'Digital Marketing': -1.0833773612976074,
#  'Industrial Design': 1.108818769454956,
#  'Competitive Strategies': 0.4596891403198242,
#  'Customer Service Systems': -1.006378412246704,
#  'Software Testing': 1.17722487449646,
#  'Data Science': -0.5641965866088867,
#  'Computer Graphics': 2.1758289337158203,
#  'Corporate Communications': 0.8792476654052734}
